# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.25.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)

# %%
#import required classes from transformers
from transformers import GPT2LMHeadModel, GPT2Tokenizer


tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# Array of prompts
prompts = [
    "The future of education is",
    "Artificial Intelligence will",
    "India in 2050 will be"
]

def generate_text(prompt, top_k, temperature):
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    output = model.generate(
        inputs,
        max_new_tokens=50,
        do_sample=True,
        top_k=top_k,
        temperature=temperature
    )

    return tokenizer.decode(output[0], skip_special_tokens=True)

# Run for all prompts
for prompt in prompts:
    print("\nPrompt:", prompt)
    result = generate_text(prompt, top_k=40, temperature=0.7)
    print("Output:", result)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Prompt: The future of education is
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output: The future of education is at stake when it comes to race, gender and sexuality. The most divisive issue in the nation's educational system is race and the future of our children. It's been a year-long battle, and now we must decide whether we want to continue
#
# Prompt: Artificial Intelligence will
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output: Artificial Intelligence will be the first technology to run on a computer running Windows 10.
#
# Microsoft announced that it will be announcing the upcoming Windows 10 Mobile operating system as a free download in its Windows 10 Mobile keynote at its Build conference in San Francisco.
#
# As
#
# Prompt: India in 2050 will be
# Output: India in 2050 will be far more powerful than our current approach.
#
# The United States remains the most powerful nation on earth because of its leadership in energy and its leadership in the international community. Our leaders have been bolder and more aggressive in protecting the environment and the environment

# %%
# Different values to test
temperatures = [0.7, 1.0, 1.3]
top_k_values = [20, 40, 80]

# Store results
results = []

for prompt in prompts:
    for temp in temperatures:
        for k in top_k_values:

            output = generate_text(prompt, top_k=k, temperature=temp)

            results.append({
                "prompt": prompt,
                "temperature": temp,
                "top_k": k,
                "output": output
            })

# Print results clearly
for r in results:
    print("\n----------------------------------")
    print("Prompt:", r["prompt"])
    print("Temperature:", r["temperature"])
    print("Top_k:", r["top_k"])
    print("Output:", r["output"])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 20
# Output: The future of education is now the subject of a new book by a distinguished and highly respected author, Professor David S. Burdick. The book's first chapter is written by a professor of education and is called, "The Future of Education."
#
# Burdick
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 40
# Output: The future of education is an academic issue, and it's time for our elected officials to take a serious look at this issue, especially those who have already committed themselves to it."
#
# Read the full report.
#
# Read the press release and follow the story on The
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 80
# Output: The future of education is now clearly under attack by the government, particularly over the lack of transparency in the curriculum and curriculum design.
#
# The new curriculum for undergraduate education is being rewritten to make it clearer to students that the purpose is to teach English as a second language and
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 20
# Output: The future of education is a process of change and the development of knowledge is a process of transformation. This is an important process of change in education. It is the path to change that students need to take to succeed in life in order to have the opportunity and resources to achieve
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 40
# Output: The future of education is far from settled. I have been told that we have to become more aware of some of the misconceptions that have been raised about our children and that we will now be more able to develop our students of all ages.
#
# We all know very little
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 80
# Output: The future of education is a challenge, and we're trying to implement it. One of the things we have to be more careful about is trying things that can be carried out in a safe manner. So to see this in school we go a bit too far [through]
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 20
# Output: The future of education is in our lifetime, but that is only the beginning. We must move forward on many fronts, so we can ensure that our communities get the information they need at the highest levels of instruction while at the same time providing for students with diverse social identities,
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 40
# Output: The future of education is increasingly on the minds of parents everywhere. And many parents continue to feel helpless and underrepresented and want their voice heard by policymakers and educators to tackle some of the problems in public policy that are facing families all over the country. We will continue to be
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 80
# Output: The future of education is in control? They claim that if teachers weren't paying for textbooks they wouldn't be delivering any extra teaching.
#
# Advertisement - Continue Reading Below
#
# In fact, how would it really work today if the only classes included in public math texts were
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 20
# Output: Artificial Intelligence will eventually make its way into the world of entertainment.
#
# "We'll see how it evolves in the next few years," says David Rauch, the executive director of the University of Minnesota's Center for Applied Artificial Intelligence (CAI). "
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 40
# Output: Artificial Intelligence will be able to play a huge part in the future of robotics and robotics medicine.
#
# In the "Beyond Robotics" video, which is part of a series on Artificial Intelligence and Robotics, he talks about how artificial intelligence can help doctors and others with
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 80
# Output: Artificial Intelligence will be a natural part of the future of the world. Many of us who are not experts in AI will be joining the field to learn about artificial intelligence at an early stage. Computers will be the first to realize that no matter how smart we are
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 20
# Output: Artificial Intelligence will also help in understanding our daily lives through artificial intelligence technologies, which are designed to improve our daily life, our sense of purpose and our social lives. Artificial Intelligence enables us to better organize and process our lives. In this way artificial intelligence helps us to
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 40
# Output: Artificial Intelligence will take full advantage of the latest advances in computing. It will create great leaps for the whole population, and there are even the usual reasons for it being used. It has all of the new capabilities needed to compete globally."
#
# In its paper,
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 80
# Output: Artificial Intelligence will probably provide a lot of time and power instead of human humans because if humans started to think like machines, this wouldn't exist. Artificial intelligence is an evolution over time, and humans will lose some of these cognitive capabilities because of the change. Why is
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 20
# Output: Artificial Intelligence will be able to recognize people, but will only have them for about 50 seconds, which means that the computer's job is far less likely than if a smart person had actually seen a person for the first time. "The goal is, at the end
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 40
# Output: Artificial Intelligence will soon be used to help with health check-in and home health check-out on patients as well and that could have a huge impact on how health care, particularly at times when the patient is not fully functional, is cared for.
#
# Researchers
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 80
# Output: Artificial Intelligence will never truly catch up. Indeed, almost 10 percent of our people will see progress on AI through their lifetime, even then, no matter what technologies that have been built. These systems can and will transform from one generation to another. At the earliest,
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 20
# Output: India in 2050 will be the first one of its kind in the world.
#
# The country has long been under pressure from China for slowing down its pace of innovation, and the rapid rise of China's economy has made it more expensive for the country to compete.
#
#
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 40
# Output: India in 2050 will be the largest economic growth scenario we have ever seen, and it's going to be a global one. We have to keep up with this," said a senior government official.
#
# The Modi government has already announced a five year plan to create a 5
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 80
# Output: India in 2050 will be estimated at Rs 1.2 trillion, according to an analysis of the forecast from the World Bank. The new figure would rise to Rs 14.4 trillion by 2050.
#
# The World Bank said the growth of the world's population at the end
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 20
# Output: India in 2050 will be the largest in the world and, in turn, will bring the biggest population change in history. It's no wonder the country is doing so well. And we are doing so well that we're beginning to notice. I think that a large part of
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 40
# Output: India in 2050 will be the worst on record; if climate change continues to increase unchecked, they say, "we will have to make our planet uninhabitable and unsustainable, where we could end up with catastrophic consequences for future generations of climate change."
#
# The report found
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 80
# Output: India in 2050 will be the poorest developed country since it started out as a coal-producing nation in 1947 and it already had 1-2 million tonnes of coal under its power plants at its peak in the 1990s. According to China's top coal producers, China's share
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 20
# Output: India in 2050 will be much cleaner than our 20th century counterparts, and in terms of CO₂, a new world temperature would result at the same rate as that of our current levels of GHB.
#
# As we discussed previously, as discussed during a lecture
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 40
# Output: India in 2050 will be achieved in two phases. One has to be initiated from the first half of this century with a broad spectrum implementation. There are a number of advantages which such a phase would create over traditional Indian schemes, such as:
#
# Improved supply chain
#
#
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 80
# Output: India in 2050 will be 30% higher than South African average.

# %%
import pandas as pd

df = pd.DataFrame(results)

# Show table
df
# Out:
#                           prompt  temperature  top_k  \
# 0     The future of education is          0.7     20
# 1     The future of education is          0.7     40
# 2     The future of education is          0.7     80
# 3     The future of education is          1.0     20
# 4     The future of education is          1.0     40
# 5     The future of education is          1.0     80
# 6     The future of education is          1.3     20
# 7     The future of education is          1.3     40
# 8     The future of education is          1.3     80
# 9   Artificial Intelligence will          0.7     20
# 10  Artificial Intelligence will          0.7     40
# 11  Artificial Intelligence will          0.7     80
# 12  Artificial Intelligence will          1.0     20
# 13  Artificial Intelligence will          1.0     40
# 14  Artificial Intelligence will          1.0     80
# 15  Artificial Intelligence will          1.3     20
# 16  Artificial Intelligence will          1.3     40
# 17  Artificial Intelligence will          1.3     80
# 18         India in 2050 will be          0.7     20
# 19         India in 2050 will be          0.7     40
# 20         India in 2050 will be          0.7     80
# 21         India in 2050 will be          1.0     20
# 22         India in 2050 will be          1.0     40
# 23         India in 2050 will be          1.0     80
# 24         India in 2050 will be          1.3     20
# 25         India in 2050 will be          1.3     40
# 26         India in 2050 will be          1.3     80
#
#                                                output
# 0   The future of education is now the subject of ...
# 1   The future of education is an academic issue, ...
# 2   The future of education is now clearly under a...
# 3   The future of education is a process of change...
# 4   The future of education is far from settled. I...
# 5   The future of education is a challenge, and we...
# 6   The future of education is in our lifetime, bu...
# 7   The future of education is increasingly on the...
# 8   The future of education is in control? They cl...
# 9   Artificial Intelligence will eventually make i...
# 10  Artificial Intelligence will be able to play a...
# 11  Artificial Intelligence will be a natural part...
# 12  Artificial Intelligence will also help in unde...
# 13  Artificial Intelligence will take full advanta...
# 14  Artificial Intelligence will probably provide ...
# 15  Artificial Intelligence will be able to recogn...
# 16  Artificial Intelligence will soon be used to h...
# 17  Artificial Intelligence will never truly catch...
# 18  India in 2050 will be the first one of its kin...
# 19  India in 2050 will be the largest economic gro...
# 20  India in 2050 will be estimated at Rs 1.2 tril...
# 21  India in 2050 will be the largest in the world...
# 22  India in 2050 will be the worst on record; if ...
# 23  India in 2050 will be the poorest developed co...
# 24  India in 2050 will be much cleaner than our 20...
# 25  India in 2050 will be achieved in two phases. ...
# 26  India in 2050 will be 30% higher than South Af...
